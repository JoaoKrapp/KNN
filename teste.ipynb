# %%
from knn import KNN, load_data
import matplotlib.pyplot as plt

# %%
def q1():
	train_features, train_labels, test_features, test_labels = load_data('./dados/grupoDados2.mat')
	
	knn = KNN(train_features, train_labels, test_features, test_labels)
	k_tests = knn.run_range_k(15)
	
	for i in range(15):
		print(f"k={k_tests['k'][i]} -> {k_tests['accuracy'][i]}")
		print(k_tests)
	
	plt.plot(k_tests['k'], k_tests['accuracy'])
	plt.show()
	
q1()

# %%
teste()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 teste()
#
# Cell In[2], line 6, in teste()
#       2 knn = KNN(train_features, train_labels, test_features, test_labels)
#       4 for col in train_features.columns:
# ----> 6 	knn = KNN(train_features, train_labels, test_features, test_labels, columns_to_remove=[col])
#       8 	k_tests = knn.run_range_k(15)
#
# File c:\Users\Joao Krapp\Desktop\Programação\FURB\Aprendizado de Maquina\KNN\knn.py:81, in KNN.__init__(self, train_features, train_labels, test_features, test_labels, columns_to_remove, columns_only)
#      78 if columns_only:
#      79     self._only_columns(columns_only)
# ---> 81 self.dist = self._generate_distance_matrix()
#
# File c:\Users\Joao Krapp\Desktop\Programação\FURB\Aprendizado de Maquina\KNN\knn.py:133, in KNN._generate_distance_matrix(self)
#     130 row_distances = []
# ...
